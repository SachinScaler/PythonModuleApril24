# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinScaler/PythonModuleApril24/blob/main/Date_Types%2C_Variables_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(100)
# Out:
# 100

# %%
print(Hello world)
# Out:
#   File "<ipython-input-2-50b4ae29d403>", line 1
#     print(Hello world)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("Hello world")
# Out:
# Hello world

# %%
Print("Hello world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d150bc9db7a2> in <cell line: 1>()
# ----> 1 Print("Hello world")
#
# NameError: name 'Print' is not defined

# %%
print('Hello world')
# Out:
# Hello world

# %%
print("Hello world')
# Out:
#   File "<ipython-input-6-42c59cf91be2>", line 1
#     print("Hello world')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello world")
# Out:
#   File "<ipython-input-7-a9b3db95ddbc>", line 1
#     print('Hello world")
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print(1+3)
# Out:
# 4

# %%
print(1*3)
# Out:
# 3

# %%
print(1-3)
# Out:
# -2

# %%
print(1/3)
# Out:
# 0.3333333333333333

# %%
print(1+3)
# Out:
# 4

# %%
print("1"+"3")# in next session when operators and polymorphishm
# Out:
# 13

# %%
print("Hello")
print('World')
# Out:
# Hello
# World

# %%
print(1235342532759235823582309542305664664565)
# Out:
# 1235342532759235823582309542305664664565

# %%
print(-1235342532759235823582309542305664664565)
# Out:
# -1235342532759235823582309542305664664565

# %%
print(True)
# Out:
# True

# %%
print(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-d6f700e50a15> in <cell line: 1>()
# ----> 1 print(true)
#
# NameError: name 'true' is not defined

# %%
print(1>2)
# Out:
# False

# %%
print(1<2)
# Out:
# True

# %%
print(None)
# Out:
# None

# %% [markdown]
# ### Optional: Complex number: 1+2i

# %%
print(1+2j)
# Out:
# (1+2j)

# %%
print(1+2i)
# Out:
#   File "<ipython-input-24-94bd8f49aab8>", line 1
#     print(1+2i)
#             ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# option
# - .2: float
# - "3.2": str
# - '1.4': str
# - -3: int

# %%
print('1.4')
# Out:
# 1.4

# %%
print("1"+"4")
# Out:
# 14

# %%
print(1+4)
# Out:
# 5

# %%
print(.2)
# Out:
# 0.2

# %%
print(0.2)
# Out:
# 0.2

# %%
print("Sachin"+"Kaushik")
# Out:
# SachinKaushik

# %%
print(1.2+3.4)
# Out:
# 4.6

# %% [markdown]
# - type

# %%
type(1)
# Out:
# int

# %%
type(.0)
# Out:
# float

# %%
type(1+2j)
# Out:
# complex

# %%
type("1"+"2")
# Out:
# str

# %%
type(1+2)
# Out:
# int

# %%
type(None)
# Out:
# NoneType

# %%
type(True)
# Out:
# bool

# %%
print(1+"2")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-c95492883789> in <cell line: 1>()
# ----> 1 print(1+"2")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(5*"3")
# Out:
# 33333

# %%
print(1+2)
# Out:
# 3

# %% [markdown]
# Variables

# %%
"x"
# Out:
# 'x'

# %%
x = 4

# %%
print(x)
# Out:
# 4

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x = 6.3
print(type(x))
# Out:
# <class 'float'>

# %%
x = 1+2
print(x)
# Out:
# 3

# %%
print(x*5)
# Out:
# 15

# %%
print(x)
# Out:
# 3

# %%
x = 1
y = 2

z = x+y
print(z)
# Out:
# 3

# %%
_name = "sachin"

# %%
1_name = "sachin"
# Out:
#   File "<ipython-input-55-2681be49c5d9>", line 1
#     1_name = "sachin"
#      ^
# SyntaxError: invalid decimal literal

# %%
1name = "sachin"
# Out:
#   File "<ipython-input-56-8e6495db02ab>", line 1
#     1name = "sachin"
#     ^
# SyntaxError: invalid decimal literal

# %%
n@me = "sachin"
# Out:
#   File "<ipython-input-57-0e7cf086b9c0>", line 1
#     n@me = "sachin"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
input()
# Out:
# sachin
# 'sachin'

# %%
print("Hello Sachin")
# Out:
# Hello Sachin

# %%
name = input()
print("Hello")
print(name)
# Out:
# sachin
# Hello
# sachin

# %%
name = input()
print("Hello")
print(name)
# Out:
# Manish
# Hello
# Manish

# %% [markdown]
# Hello Chanchal ? How

# %%
name = input()
print("Hello",name)
# Out:
# Manish
# Hello Manish

# %%
print("Hello","World","?")
# Out:
# Hello World ?

# %%
x = 3
y = 'hello'
num = y
y = 5
print(num, y)
# Out:
# hello 5

# %%
# how to take integers as input

num1 = input()
num2 = input()
print(num1+num2)
# Out:
# 3
# 5
# 35

# %%
num1 = input()
print(type(num1))
# Out:
# 2
# <class 'str'>

# %%
num1 = int(input())
print(type(num1))
# Out:
# 1
# <class 'int'>

# %% [markdown]
# Fix this code to print sum of numbers:
# ```
# num1 = input()
# num2 = input()
# print(num1+num2)
#
# ```

# %% [markdown]
# ### DOUBT SOLVING

# %%
num1 = float(input())
print(type(num1))
# Out:
# 4
# <class 'float'>

# %%
num1
# Out:
# 4.0

# %%
print(id(num1))
# Out:
# 134062945414576

# %%
num2 = 5
print(id(num1))
print(id(num2))
# Out:
# 134062945414576
# 134063995421040

# %%
y = "Hello"
x =y
print(id(x), id(y))
# Out:
# 134062945559856 134062945559856

# %%
x = 10
print(id(x), id(y))
# Out:
# 134063995421200 134062945559856

# %%
a: int = 1 # typehint

# %%
a = "sachin"

# %%
#Print("1"+"4") and Print("1""4") are same ?

# %%
print("1""4")
# Out:
# 14

# %%
print("1"+"4")
# Out:
# 14

# %%
print("Hey guy's")
# Out:
# Hey guy's

# %%
print('Hey guy"s')
# Out:
# Hey guy"s

# %%
print('Hey guy\'s')
# Out:
# Hey guy's

# %%
print("\n")# this adds new line

# %%
print("\t")# this adds tab space or 4 whitespaces

# %%
print(''' hi
hi
''')
# Out:
#  hi
# hi

# %% [markdown]
# ### Conditional Statements:
#
# Rahul: How we can put this constraints
# 1 <= len(A) <= 15 Characters in A are in lowercase English Alphabets.
